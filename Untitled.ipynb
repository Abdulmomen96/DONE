# %%
from sklearn.datasets import fetch_openml
from tqdm import trange
import numpy as np
import random
import json
import os
import pandas as pd

# %%
random.seed(1)
np.random.seed(1)
NUM_USERS = 32  
NUM_LABELS = 10
# Setup directory for train/test data
train_path = './data/train/mnist_train.json'
test_path = './data/test/mnist_test.json'
dir_path = os.path.dirname(train_path)
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
dir_path = os.path.dirname(test_path)
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

# %%
# Get MNIST data, normalize, and divide by level
mnist = fetch_openml(name='mnist_784', data_home='./data')

mu = np.mean(mnist.data.astype(np.float32), 0)
sigma = np.std(mnist.data.astype(np.float32), 0)
mnist.data = (mnist.data.astype(np.float32) - mu)/(sigma+0.001)
mnist_data = []
mnist.data = mnist.data.to_numpy()
for i in trange(10):
    idx = mnist.target.astype(np.int32)==i
    mnist_data.append(mnist.data[idx])

print("\nNumb samples of each label:\n", [len(v) for v in mnist_data])
# Out:
# C:\Users\VarjoPC1\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# 100%|██████████| 10/10 [00:00<00:00, 59.83it/s]
# Numb samples of each label:
#  [6903, 7877, 6990, 7141, 6824, 6313, 6876, 7293, 6825, 6958]

# %%
###### CREATE USER DATA SPLIT #######
# Assign 100 samples to each user
X = [[] for _ in range(NUM_USERS)]
y = [[] for _ in range(NUM_USERS)]
idx = np.zeros(10, dtype=np.int64)
for user in range(NUM_USERS):
    for j in range(NUM_LABELS):  # 3 labels for each users
        #l = (2*user+j)%10
        l = (user + j) % 10
        print("L:", l)
        X[user] += mnist_data[l][idx[l]:idx[l]+10].tolist()
        y[user] += (l*np.ones(10)).tolist()
        idx[l] += 10

print("IDX1:", idx)  # counting samples for each labels

# Assign remaining sample by power law
user = 0
props = np.random.lognormal(
    0, 2., (10, NUM_USERS, NUM_LABELS))  # last 5 is 5 labels
props = np.array([[[len(v)-NUM_USERS]] for v in mnist_data]) * \
    props/np.sum(props, (1, 2), keepdims=True)
# print("here:",props/np.sum(props,(1,2), keepdims=True))
#props = np.array([[[len(v)-100]] for v in mnist_data]) * \
#    props/np.sum(props, (1, 2), keepdims=True)
#idx = 1000*np.ones(10, dtype=np.int64)
# print("here2:",props)
for user in trange(NUM_USERS):
    for j in range(NUM_LABELS):  # 4 labels for each users
        # l = (2*user+j)%10
        l = (user + j) % 10
        num_samples = int(props[l, user//int(NUM_USERS/10), j])
        numran1 = random.randint(1, 100)
        numran2 = random.randint(1, 5)
        num_samples = (num_samples) * numran2 + numran1 + 150
        if(NUM_USERS <= 20):
            num_samples = num_samples * 2
        if idx[l] + num_samples < len(mnist_data[l]):
            X[user] += mnist_data[l][idx[l]:idx[l]+num_samples].tolist()
            y[user] += (l*np.ones(num_samples)).tolist()
            idx[l] += num_samples
            print("check len os user:", user, j,
                  "len data", len(X[user]), num_samples)

print("IDX2:", idx) # counting samples for each labels

# Create data structure
train_data = {'users': [], 'user_data':{}, 'num_samples':[]}
test_data = {'users': [], 'user_data':{}, 'num_samples':[]}
# Out:
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 7
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 8
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 9
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 0
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 1
# L: 2
# L: 3
# L: 4
# L: 5
# L: 6
# L: 7
# L: 8
# L: 9
# L: 0
# IDX1: [320 320 320 320 320 320 320 320 320 320]
#   9%|▉         | 3/32 [00:00<00:01, 28.80it/s]
# check len os user: 0 0 len data 633 533
# check len os user: 0 1 len data 881 248
# check len os user: 0 2 len data 1064 183
# check len os user: 0 3 len data 1278 214
# check len os user: 0 4 len data 1489 211
# check len os user: 0 5 len data 1676 187
# check len os user: 0 6 len data 2085 409
# check len os user: 0 7 len data 2293 208
# check len os user: 0 8 len data 2529 236
# check len os user: 0 9 len data 2769 240
# check len os user: 1 0 len data 287 187
# check len os user: 1 1 len data 537 250
# check len os user: 1 2 len data 729 192
# check len os user: 1 3 len data 882 153
# check len os user: 1 4 len data 1116 234
# check len os user: 1 5 len data 1272 156
# check len os user: 1 6 len data 1512 240
# check len os user: 1 7 len data 1737 225
# check len os user: 1 8 len data 1957 220
# check len os user: 1 9 len data 2209 252
# check len os user: 2 0 len data 414 314
# check len os user: 2 1 len data 621 207
# check len os user: 2 2 len data 815 194
# check len os user: 2 3 len data 1063 248
# check len os user: 2 4 len data 1262 199
# check len os user: 2 5 len data 1471 209
# check len os user: 2 6 len data 1707 236
# check len os user: 2 7 len data 1887 180
# check len os user: 2 8 len data 2068 181
# check len os user: 2 9 len data 2401 333
# check len os user: 3 0 len data 325 225
# check len os user: 3 1 len data 565 240
# check len os user: 3 2 len data 754 189
# check len os user: 3 3 len data 988 234
# check len os user: 3 4 len data 1203 215
# check len os user: 3 5 len data 1429 226
# check len os user: 3 6 len data 1645 216
# check len os user: 3 7 len data 1891 246
# check len os user: 3 8 len data 2095 204
# check len os user: 3 9 len data 2292 197
# check len os user: 4 0 len data 373 273
# check len os user: 4 1 len data 571 198
# check len os user: 4 2 len data 946 375
# check len os user: 4 3 len data 1248 302
# check len os user: 4 4 len data 1465 217
# check len os user: 4 5 len data 1663 198
# check len os user: 4 6 len data 1909 246
# check len os user: 4 7 len data 2120 211
# check len os user: 4 8 len data 2320 200
#  19%|█▉        | 6/32 [00:00<00:01, 25.83it/s]
# check len os user: 4 9 len data 2556 236
# check len os user: 5 0 len data 301 201
# check len os user: 5 1 len data 493 192
# check len os user: 5 2 len data 688 195
# check len os user: 5 3 len data 1011 323
# check len os user: 5 4 len data 1241 230
# check len os user: 5 5 len data 1421 180
# check len os user: 5 6 len data 1637 216
# check len os user: 5 7 len data 1870 233
# check len os user: 5 8 len data 2100 230
# check len os user: 5 9 len data 2335 235
#  28%|██▊       | 9/32 [00:00<00:00, 23.76it/s]
# check len os user: 6 0 len data 438 338
# check len os user: 6 1 len data 638 200
# check len os user: 6 2 len data 805 167
# check len os user: 6 3 len data 1055 250
# check len os user: 6 4 len data 1300 245
# check len os user: 6 5 len data 1462 162
# check len os user: 6 6 len data 1664 202
# check len os user: 6 7 len data 1927 263
# check len os user: 6 8 len data 2142 215
# check len os user: 6 9 len data 2355 213
# check len os user: 7 0 len data 322 222
# check len os user: 7 1 len data 708 386
# check len os user: 7 2 len data 928 220
# check len os user: 7 3 len data 1178 250
# check len os user: 7 4 len data 1392 214
# check len os user: 7 5 len data 1548 156
# check len os user: 7 6 len data 1788 240
# check len os user: 7 7 len data 2174 386
# check len os user: 7 8 len data 2375 201
# check len os user: 7 9 len data 2602 227
# check len os user: 8 0 len data 255 155
# check len os user: 8 1 len data 424 169
# check len os user: 8 2 len data 649 225
# check len os user: 8 3 len data 905 256
# check len os user: 8 4 len data 1120 215
# check len os user: 8 5 len data 1295 175
# check len os user: 8 6 len data 1469 174
# check len os user: 8 7 len data 1657 188
# check len os user: 8 8 len data 2123 466
# check len os user: 8 9 len data 2316 193
# check len os user: 9 0 len data 281 181
# check len os user: 9 1 len data 517 236
# check len os user: 9 2 len data 729 212
# check len os user: 9 3 len data 1003 274
# check len os user: 9 4 len data 1211 208
# check len os user: 9 5 len data 1437 226
# check len os user: 9 6 len data 1647 210
# check len os user: 9 7 len data 1822 175
# check len os user: 9 8 len data 1986 164
# check len os user: 9 9 len data 2230 244
# check len os user: 10 0 len data 277 177
# check len os user: 10 1 len data 494 217
# check len os user: 10 2 len data 679 185
# check len os user: 10 3 len data 906 227
# check len os user: 10 4 len data 1067 161
# check len os user: 10 5 len data 1275 208
# check len os user: 10 6 len data 1600 325
# check len os user: 10 7 len data 1820 220
# check len os user: 10 8 len data 2051 231
# check len os user: 10 9 len data 2263 212
# check len os user: 11 0 len data 331 231
# check len os user: 11 1 len data 547 216
# check len os user: 11 2 len data 767 220
# check len os user: 11 3 len data 928 161
# check len os user: 11 4 len data 1095 167
#  47%|████▋     | 15/32 [00:00<00:00, 23.49it/s]
# check len os user: 11 5 len data 1252 157
# check len os user: 11 6 len data 1425 173
# check len os user: 11 7 len data 1615 190
# check len os user: 11 8 len data 1861 246
# check len os user: 11 9 len data 2125 264
# check len os user: 12 0 len data 295 195
# check len os user: 12 1 len data 447 152
# check len os user: 12 2 len data 712 265
# check len os user: 12 3 len data 890 178
# check len os user: 12 4 len data 1099 209
# check len os user: 12 5 len data 1369 270
# check len os user: 12 6 len data 1587 218
# check len os user: 12 7 len data 1792 205
# check len os user: 12 8 len data 1990 198
# check len os user: 12 9 len data 2182 192
# check len os user: 13 0 len data 345 245
# check len os user: 13 1 len data 571 226
# check len os user: 13 2 len data 785 214
# check len os user: 13 3 len data 1021 236
# check len os user: 13 4 len data 1944 923
# check len os user: 13 5 len data 2158 214
# check len os user: 13 6 len data 2350 192
# check len os user: 13 7 len data 3119 769
# check len os user: 13 8 len data 3282 163
# check len os user: 13 9 len data 3467 185
# check len os user: 14 0 len data 345 245
# check len os user: 14 1 len data 611 266
# check len os user: 14 2 len data 789 178
# check len os user: 14 3 len data 1029 240
# check len os user: 14 4 len data 1243 214
# check len os user: 14 5 len data 1448 205
# check len os user: 14 6 len data 1681 233
# check len os user: 14 7 len data 1862 181
# check len os user: 14 8 len data 2117 255
# check len os user: 14 9 len data 2414 297
#  59%|█████▉    | 19/32 [00:00<00:00, 24.40it/s]
# check len os user: 15 0 len data 272 172
# check len os user: 15 1 len data 491 219
# check len os user: 15 2 len data 676 185
# check len os user: 15 3 len data 1038 362
# check len os user: 15 4 len data 1224 186
# check len os user: 15 5 len data 1445 221
# check len os user: 15 6 len data 2000 555
# check len os user: 15 7 len data 2346 346
# check len os user: 15 8 len data 2596 250
# check len os user: 15 9 len data 2774 178
# check len os user: 16 0 len data 321 221
# check len os user: 16 1 len data 515 194
# check len os user: 16 2 len data 719 204
# check len os user: 16 3 len data 934 215
# check len os user: 16 4 len data 1104 170
# check len os user: 16 5 len data 1294 190
# check len os user: 16 6 len data 1604 310
# check len os user: 16 7 len data 1764 160
# check len os user: 16 8 len data 1991 227
# check len os user: 16 9 len data 2215 224
# check len os user: 17 0 len data 297 197
# check len os user: 17 1 len data 485 188
# check len os user: 17 2 len data 709 224
# check len os user: 17 3 len data 921 212
# check len os user: 17 4 len data 1156 235
# check len os user: 17 5 len data 1346 190
# check len os user: 17 6 len data 1585 239
# check len os user: 17 7 len data 1755 170
# check len os user: 17 8 len data 1955 200
# check len os user: 17 9 len data 2148 193
# check len os user: 18 0 len data 350 250
# check len os user: 18 1 len data 524 174
# check len os user: 18 2 len data 746 222
# check len os user: 18 3 len data 984 238
# check len os user: 18 4 len data 1156 172
# check len os user: 18 5 len data 1590 434
# check len os user: 18 6 len data 1810 220
# check len os user: 18 7 len data 2196 386
# check len os user: 18 8 len data 2438 242
# check len os user: 18 9 len data 2633 195
#  69%|██████▉   | 22/32 [00:00<00:00, 24.04it/s]
# check len os user: 19 0 len data 277 177
# check len os user: 19 1 len data 467 190
# check len os user: 19 2 len data 619 152
# check len os user: 19 3 len data 1117 498
# check len os user: 19 4 len data 1356 239
# check len os user: 19 5 len data 1557 201
# check len os user: 19 6 len data 1767 210
# check len os user: 19 7 len data 1932 165
# check len os user: 19 8 len data 2159 227
# check len os user: 19 9 len data 2339 180
# check len os user: 20 0 len data 278 178
# check len os user: 20 1 len data 533 255
# check len os user: 20 2 len data 780 247
# check len os user: 20 3 len data 1018 238
# check len os user: 20 4 len data 1202 184
# check len os user: 20 5 len data 1422 220
# check len os user: 20 6 len data 1612 190
# check len os user: 20 7 len data 1794 182
# check len os user: 20 8 len data 2021 227
# check len os user: 20 9 len data 2183 162
# check len os user: 21 0 len data 262 162
# check len os user: 21 1 len data 495 233
# check len os user: 21 2 len data 811 316
# check len os user: 21 3 len data 1007 196
# check len os user: 21 4 len data 1505 498
# check len os user: 21 5 len data 1716 211
# check len os user: 21 6 len data 1955 239
# check len os user: 21 7 len data 2166 211
# check len os user: 21 8 len data 2386 220
# check len os user: 21 9 len data 2676 290
# check len os user: 22 0 len data 262 162
# check len os user: 22 1 len data 442 180
# check len os user: 22 2 len data 624 182
# check len os user: 22 3 len data 784 160
# check len os user: 22 4 len data 1006 222
# check len os user: 22 5 len data 1255 249
# check len os user: 22 6 len data 1408 153
# check len os user: 22 7 len data 1599 191
# check len os user: 22 8 len data 1829 230
# check len os user: 22 9 len data 2122 293
# check len os user: 23 0 len data 336 236
# check len os user: 23 1 len data 516 180
# check len os user: 23 2 len data 752 236
# check len os user: 23 3 len data 925 173
# check len os user: 23 4 len data 1094 169
# check len os user: 23 5 len data 1284 190
# check len os user: 23 6 len data 1525 241
# check len os user: 23 7 len data 1795 270
# check len os user: 23 8 len data 1964 169
# check len os user: 23 9 len data 2138 174
# check len os user: 24 0 len data 350 250
# check len os user: 24 1 len data 600 250
# check len os user: 24 2 len data 835 235
# check len os user: 24 3 len data 1097 262
# check len os user: 24 4 len data 1276 179
# check len os user: 24 5 len data 1482 206
# check len os user: 24 6 len data 1653 171
# check len os user: 24 7 len data 1895 242
# check len os user: 24 8 len data 2080 185
# check len os user: 24 9 len data 2318 238
# check len os user: 25 0 len data 306 206
# check len os user: 25 1 len data 514 208
# check len os user: 25 2 len data 721 207
# check len os user: 25 3 len data 945 224
# check len os user: 25 4 len data 1188 243
# check len os user: 25 5 len data 1369 181
# check len os user: 25 6 len data 1582 213
# check len os user: 25 7 len data 1827 245
# check len os user: 25 8 len data 2131 304
# check len os user: 25 9 len data 2415 284
# 100%|██████████| 32/32 [00:01<00:00, 27.94it/s]
# check len os user: 26 0 len data 341 241
# check len os user: 26 1 len data 567 226
# check len os user: 26 2 len data 741 174
# check len os user: 26 3 len data 931 190
# check len os user: 26 5 len data 1114 183
# check len os user: 26 6 len data 1282 168
# check len os user: 26 7 len data 1529 247
# check len os user: 26 8 len data 1772 243
# check len os user: 27 0 len data 334 234
# check len os user: 27 1 len data 574 240
# check len os user: 27 2 len data 776 202
# check len os user: 27 4 len data 955 179
# check len os user: 27 5 len data 1149 194
# check len os user: 27 6 len data 1393 244
# check len os user: 27 7 len data 1626 233
# check len os user: 28 0 len data 339 239
# check len os user: 28 1 len data 615 276
# check len os user: 28 3 len data 808 193
# check len os user: 28 4 len data 1050 242
# check len os user: 28 6 len data 1294 244
# check len os user: 28 9 len data 1525 231
# check len os user: 29 0 len data 349 249
# check len os user: 29 2 len data 676 327
# check len os user: 30 1 len data 330 230
# check len os user: 30 9 len data 545 215
# check len os user: 31 0 len data 270 170
# IDX2: [6890 7533 6946 6976 6677 6184 6716 7291 6823 6855]

# %%
# Setup 5 users
# for i in trange(5, ncols=120):
for i in range(NUM_USERS):
    uname = 'f_{0:05d}'.format(i)
    
    combined = list(zip(X[i], y[i]))
    random.shuffle(combined)
    X[i][:], y[i][:] = zip(*combined)
    num_samples = len(X[i])
    train_len = int(0.75*num_samples)
    test_len = num_samples - train_len
    
    train_data['users'].append(uname) 
    train_data['user_data'][uname] = {'x': X[i][:train_len], 'y': y[i][:train_len]}
    train_data['num_samples'].append(train_len)
    test_data['users'].append(uname)
    test_data['user_data'][uname] = {'x': X[i][train_len:], 'y': y[i][train_len:]}
    test_data['num_samples'].append(test_len)

print("Num_samples:", train_data['num_samples'])
print("Total_samples:",sum(train_data['num_samples']))
    
with open(train_path,'w') as outfile:
    json.dump(train_data, outfile)
with open(test_path, 'w') as outfile:
    json.dump(test_data, outfile)

print("Finish Generating Samples")
# Out:
# Num_samples: [2076, 1656, 1800, 1719, 1917, 1751, 1766, 1951, 1737, 1672, 1697, 1593, 1636, 2600, 1810, 2080, 1661, 1611, 1974, 1754, 1637, 2007, 1591, 1603, 1738, 1811, 1329, 1219, 1143, 507, 408, 202]
# Total_samples: 51656
# Finish Generating Samples

# %%
train_path
# Out:
# './data/train/mnist_train.json'

# %%
device = torch.device("cuda:{}".format(gpu) if torch.cuda.is_available() and gpu != -1 else "cpu")

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
print(f"Is CUDA supported by this system?{torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
 
# Storing ID of current CUDA device
cuda_id = torch.cuda.current_device()
print(f"ID of current CUDA device:{torch.cuda.current_device()}")
       
print(f"Name of current CUDA device:{torch.cuda.get_device_name(cuda_id)}")
# Out:
# Is CUDA supported by this system?True
# CUDA version: 11.8
# ID of current CUDA device:0
# Name of current CUDA device:NVIDIA GeForce RTX 2080 Ti

# %%
from sklearn.datasets import fetch_openml
from tqdm import trange
import numpy as np
import random
import json
import os
import tensorflow as tf
#from tensorflow.examples.tutorials.mnist import input_data

random.seed(1)
np.random.seed(1)
NUM_USERS = 32
NUM_LABELS = 3

# Setup directory for train/test data
train_path = './data/train/fashion_train.json'
test_path = './data/test/fashion_test.json'
dir_path = os.path.dirname(train_path)
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
dir_path = os.path.dirname(test_path)
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
mnist_data_image = []
mnist_data_lable = []
mnist_data_image.extend(train_images)
mnist_data_image.extend(test_images)
mnist_data_lable.extend(train_labels)
mnist_data_lable.extend(test_labels)

mu = np.mean(mnist_data_image)
sigma = np.std(mnist_data_image)
nom_Fashion_data = (mnist_data_image - mu)/(sigma+0.001)
nom_Fashion_lable = np.array(mnist_data_lable)
mnist_data = []
for i in trange(10):
    idx = nom_Fashion_lable == i
    mnist_data.append(nom_Fashion_data[idx])

print([len(v) for v in mnist_data])


###### CREATE USER DATA SPLIT #######
# Assign 100 samples to each user
X = [[] for _ in range(NUM_USERS)]
y = [[] for _ in range(NUM_USERS)]
idx = np.zeros(10, dtype=np.int64)
for user in range(NUM_USERS):
    for j in range(NUM_LABELS):  # 3 labels for each users
        #l = (2*user+j)%10
        l = (user + j) % 10
        print("L:", l)
        X[user] += mnist_data[l][idx[l]:idx[l]+10].tolist()
        y[user] += (l*np.ones(10)).tolist()
        idx[l] += 10

print("IDX1:", idx)  # counting samples for each labels

# Assign remaining sample by power law
user = 0
props = np.random.lognormal(
    0, 2., (10, NUM_USERS, NUM_LABELS))  # last 5 is 5 labels
# print("here:",props/np.sum(props,(1,2), keepdims=True))
props = np.array([[[len(v)-NUM_USERS]] for v in mnist_data]) * \
    props/np.sum(props, (1, 2), keepdims=True)
#idx = 1000*np.ones(10, dtype=np.int64)
# print("here2:",props)
for user in trange(NUM_USERS):
    for j in range(NUM_LABELS):  # 4 labels for each users
        # l = (2*user+j)%10
        l = (user + j) % 10
        num_samples = int(props[l, user//int(NUM_USERS/10), j])
        numran1 = random.randint(10, 200)
        numran2 = random.randint(1, 10)
        num_samples = (num_samples) * numran2 + numran1 + 200
        if(NUM_USERS <= 20): 
            num_samples = num_samples * 2
        if idx[l] + num_samples < len(mnist_data[l]):
            X[user] += mnist_data[l][idx[l]:idx[l]+num_samples].tolist()
            y[user] += (l*np.ones(num_samples)).tolist()
            idx[l] += num_samples
            print("check len os user:", user, j,
                  "len data", len(X[user]), num_samples)

print("IDX2:", idx)  # counting samples for each labels
# Create data structure
train_data = {'users': [], 'user_data': {}, 'num_samples': []}
test_data = {'users': [], 'user_data': {}, 'num_samples': []}

# Setup 5 users
# for i in trange(5, ncols=120):
for i in range(NUM_USERS):
    uname = 'f_{0:05d}'.format(i)

    combined = list(zip(X[i], y[i]))
    random.shuffle(combined)
    X[i][:], y[i][:] = zip(*combined)
    num_samples = len(X[i])
    train_len = int(0.75*num_samples)
    test_len = num_samples - train_len

    train_data['users'].append(uname)
    train_data['user_data'][uname] = {
        'x': X[i][:train_len], 'y': y[i][:train_len]}
    train_data['num_samples'].append(train_len)
    test_data['users'].append(uname)
    test_data['user_data'][uname] = {
        'x': X[i][train_len:], 'y': y[i][train_len:]}
    test_data['num_samples'].append(test_len)

print("Num_samples:", train_data['num_samples'])
print("Total_samples:",sum(train_data['num_samples'] + test_data['num_samples']))
  

with open(train_path, 'w') as outfile:
    json.dump(train_data, outfile)
with open(test_path, 'w') as outfile:
    json.dump(test_data, outfile)

print("Finish Generating Samples")
# Out:
# WARNING:tensorflow:From C:\Users\VarjoPC1\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# 100%|██████████| 10/10 [00:00<00:00, 100.80it/s]
# [7000, 7000, 7000, 7000, 7000, 7000, 7000, 7000, 7000, 7000]
# L: 0
# L: 1
# L: 2
# L: 1
# L: 2
# L: 3
# L: 2
# L: 3
# L: 4
# L: 3
# L: 4
# L: 5
# L: 4
# L: 5
# L: 6
# L: 5
# L: 6
# L: 7
# L: 6
# L: 7
# L: 8
# L: 7
# L: 8
# L: 9
# L: 8
# L: 9
# L: 0
# L: 9
# L: 0
# L: 1
# L: 0
# L: 1
# L: 2
# L: 1
# L: 2
# L: 3
# L: 2
# L: 3
# L: 4
# L: 3
# L: 4
# L: 5
# L: 4
# L: 5
# L: 6
# L: 5
# L: 6
# L: 7
# L: 6
# L: 7
# L: 8
# L: 7
# L: 8
# L: 9
# L: 8
# L: 9
# L: 0
# L: 9
# L: 0
# L: 1
# L: 0
# L: 1
# L: 2
# L: 1
# L: 2
# L: 3
# L: 2
# L: 3
# L: 4
# L: 3
# L: 4
# L: 5
# L: 4
# L: 5
# L: 6
# L: 5
# L: 6
# L: 7
# L: 6
# L: 7
# L: 8
# L: 7
# L: 8
# L: 9
# L: 8
# L: 9
# L: 0
# L: 9
# L: 0
# L: 1
# L: 0
# L: 1
# L: 2
# L: 1
# L: 2
# L: 3
# IDX1: [100 110 110 100  90  90  90  90  90  90]
#   0%|          | 0/32 [00:00<?, ?it/s]
# check len os user: 0 0 len data 3954 3924
# check len os user: 0 1 len data 4240 286
#   3%|▎         | 1/32 [00:00<00:09,  3.40it/s]
# check len os user: 0 2 len data 4760 520
# check len os user: 1 0 len data 395 365
# check len os user: 1 1 len data 1387 992
# check len os user: 1 2 len data 1660 273
# check len os user: 2 0 len data 795 765
# check len os user: 2 1 len data 1167 372
# check len os user: 2 2 len data 1540 373
# check len os user: 3 0 len data 474 444
# check len os user: 3 1 len data 756 282
# check len os user: 3 2 len data 1131 375
# check len os user: 4 0 len data 328 298
# check len os user:
#  16%|█▌        | 5/32 [00:00<00:02,  9.92it/s]
#  4 1 len data 583 255
# check len os user: 4 2 len data 1004 421
# check len os user: 5 0 len data 298 268
# check len os user: 5 1 len data 1043 745
# check len os user: 5 2 len data 1366 323
# check len os user: 6 0 len data 383 353
# check len os user: 6 1 len data 817 434
# check len os user: 6 2 len data 1172 355
# check len os user: 7 0 len data 356 326
# check len os user: 7 1 len data 771 415
#  25%|██▌       | 8/32 [00:00<00:02, 10.55it/s]
# check len os user: 7 2 len data 3238 2467
# check len os user: 8 0 len data 854 824
# check len os user: 8 1 len data 1206 352
# check len os user: 8 2 len data 1598 392
# check len os user: 9 0 len data 1860 1830
# check len os user: 9 2 len data 2187 327
# check len os user: 10 0 len data 443 413
# check len os user: 10 1 len data 975 532
#  44%|████▍     | 14/32 [00:01<00:01, 12.08it/s]
# check len os user: 10 2 len data 5151 4176
# check len os user: 11 0 len data 474 444
# check len os user: 11 1 len data 837 363
# check len os user: 11 2 len data 1273 436
# check len os user: 12 1 len data 346 316
# check len os user: 12 2 len data 739 393
# check len os user: 13 0 len data 3503 3473
# check len os user: 13 1 len data 4295 792
# check len os user: 13 2 len data 4674 379
# check len os user: 14 0 len data 267 237
# check len os user: 14 1 len data 645 378
#  62%|██████▎   | 20/32 [00:01<00:00, 14.84it/s]
# check len os user: 14 2 len data 989 344
# check len os user: 15 0 len data 427 397
# check len os user: 15 1 len data 809 382
# check len os user: 15 2 len data 1167 358
# check len os user: 16 0 len data 491 461
# check len os user: 16 1 len data 876 385
# check len os user: 16 2 len data 1129 253
# check len os user: 17 0 len data 317 287
# check len os user: 17 1 len data 1712 1395
# check len os user: 17 2 len data 2570 858
# check len os user: 18 0 len data 361 331
# check len os user: 18 1 len data 839 478
# check len os user: 18 2 len data 1147 308
# check len os user: 19 0 len data 470 440
# check len os user: 19 1 len data 880 410
# check len os user: 19 2 len data 1278 398
# check len os user: 20 0 len data 408 378
# check len os user: 20 1 len data 761 353
# check len os user: 21 0 len data 363 333
# check len os user: 21 2 len data 759 396
# check len os user: 22 1 len data 877 847
# check len os user: 22 2 len data 1177 300
# check len os user: 23 1 len data 399 369
# check len os user: 23 2 len data 701 302
# check len os user: 24 0 len data 420 390
# check len os user: 24 1 len data 697 277
# check len os user: 24 2 len data 1067 370
# 100%|██████████| 32/32 [00:02<00:00, 14.23it/s]
# check len os user: 25 0 len data 288 258
# check len os user: 25 1 len data 894 606
# check len os user: 25 2 len data 1112 218
# check len os user: 26 0 len data 263 233
# check len os user: 26 1 len data 653 390
# check len os user: 26 2 len data 1334 681
# check len os user: 27 0 len data 312 282
# check len os user: 27 1 len data 984 672
# check len os user: 28 0 len data 257 227
# check len os user: 28 1 len data 507 250
# check len os user: 28 2 len data 975 468
# check len os user: 29 1 len data 445 415
# check len os user: 29 2 len data 1569 1124
# check len os user: 30 1 len data 291 261
# check len os user: 31 0 len data 2364 2334
# check len os user: 31 2 len data 2631 267
# IDX2: [6808 6867 6926 6924 3524 2979 4005 3093 5243 6765]
# Num_samples: [3570, 1245, 1155, 848, 753, 1024, 879, 2428, 1198, 1640, 3863, 954, 554, 3505, 741, 875, 846, 1927, 860, 958, 570, 569, 882, 525, 800, 834, 1000, 738, 731, 1176, 218, 1973]
# Total_samples: 53134
# Finish Generating Samples

# %%
from sklearn.datasets import fetch_openml
from tqdm import trange
import numpy as np
import random
import json
import os
import torch
import torchvision
import torchvision.transforms as transforms
transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False,download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=len(trainset.data),shuffle=False)
testloader = torch.utils.data.DataLoader(testset, batch_size=len(testset.data),shuffle=False)

for _, train_data in enumerate(trainloader,0):
    trainset.data, trainset.targets = train_data
for _, train_data in enumerate(testloader,0):
    testset.data, testset.targets = train_data

random.seed(1)
np.random.seed(1)
NUM_USERS = 20 # should be muitiple of 10
NUM_LABELS = 3
# Setup directory for train/test data
train_path = './data/train/cifa_train.json'
test_path = './data/test/cifa_test.json'
dir_path = os.path.dirname(train_path)
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
dir_path = os.path.dirname(test_path)
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

cifa_data_image = []
cifa_data_label = []

cifa_data_image.extend(trainset.data.cpu().detach().numpy())
cifa_data_image.extend(testset.data.cpu().detach().numpy())
cifa_data_label.extend(trainset.targets.cpu().detach().numpy())
cifa_data_label.extend(testset.targets.cpu().detach().numpy())
cifa_data_image = np.array(cifa_data_image)
cifa_data_label = np.array(cifa_data_label)

cifa_data = []
for i in trange(10):
    idx = cifa_data_label==i
    cifa_data.append(cifa_data_image[idx])


print("\nNumb samples of each label:\n", [len(v) for v in cifa_data])
users_lables = []

###### CREATE USER DATA SPLIT #######
# Assign 100 samples to each user
X = [[] for _ in range(NUM_USERS)]
y = [[] for _ in range(NUM_USERS)]
idx = np.zeros(10, dtype=np.int64)
for user in range(NUM_USERS):
    for j in range(NUM_LABELS):  # 3 labels for each users
        #l = (2*user+j)%10
        l = (user + j) % 10
        print("L:", l)
        X[user] += cifa_data[l][idx[l]:idx[l]+10].tolist()
        y[user] += (l*np.ones(10)).tolist()
        idx[l] += 10

print("IDX1:", idx)  # counting samples for each labels

# Assign remaining sample by power law
user = 0
props = np.random.lognormal(
    0, 2., (10, NUM_USERS, NUM_LABELS))  # last 5 is 5 labels
props = np.array([[[len(v)-NUM_USERS]] for v in cifa_data]) * \
    props/np.sum(props, (1, 2), keepdims=True)
# print("here:",props/np.sum(props,(1,2), keepdims=True))
#props = np.array([[[len(v)-100]] for v in mnist_data]) * \
#    props/np.sum(props, (1, 2), keepdims=True)
#idx = 1000*np.ones(10, dtype=np.int64)
# print("here2:",props)
for user in trange(NUM_USERS):
    for j in range(NUM_LABELS):  # 4 labels for each users
        # l = (2*user+j)%10
        l = (user + j) % 10
        num_samples = int(props[l, user//int(NUM_USERS/10), j])
        numran1 = random.randint(10, 200)
        numran2 = random.randint(1, 10)
        num_samples = (num_samples) * numran2 + numran1 + 200
        if(NUM_USERS <= 20): 
            num_samples = num_samples * 2
        if idx[l] + num_samples < len(cifa_data[l]):
            X[user] += cifa_data[l][idx[l]:idx[l]+num_samples].tolist()
            y[user] += (l*np.ones(num_samples)).tolist()
            idx[l] += num_samples
            print("check len os user:", user, j,
                  "len data", len(X[user]), num_samples)

print("IDX2:", idx) # counting samples for each labels

# Create data structure
train_data = {'users': [], 'user_data':{}, 'num_samples':[]}
test_data = {'users': [], 'user_data':{}, 'num_samples':[]}

# Setup 5 users
# for i in trange(5, ncols=120):
for i in range(NUM_USERS):
    uname = 'f_{0:05d}'.format(i)
    
    combined = list(zip(X[i], y[i]))
    random.shuffle(combined)
    X[i][:], y[i][:] = zip(*combined)
    num_samples = len(X[i])
    train_len = int(0.75*num_samples)
    test_len = num_samples - train_len
    
    train_data['users'].append(uname) 
    train_data['user_data'][uname] = {'x': X[i][:train_len], 'y': y[i][:train_len]}
    train_data['num_samples'].append(train_len)
    test_data['users'].append(uname)
    test_data['user_data'][uname] = {'x': X[i][train_len:], 'y': y[i][train_len:]}
    test_data['num_samples'].append(test_len)

print("Num_samples:", train_data['num_samples'])
print("Total_samples:",sum(train_data['num_samples'] + test_data['num_samples']))
    
with open(train_path,'w') as outfile:
    json.dump(train_data, outfile)
with open(test_path, 'w') as outfile:
    json.dump(test_data, outfile)

print("Finish Generating Samples")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100%|██████████| 10/10 [00:00<00:00, 43.17it/s]
# Numb samples of each label:
#  [6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000]
# L: 0
# L: 1
# L: 2
# L: 1
# L: 2
# L: 3
# L: 2
# L: 3
# L: 4
# L: 3
# L: 4
# L: 5
# L: 4
# L: 5
# L: 6
# L: 5
# L: 6
# L: 7
# L: 6
# L: 7
# L: 8
# L: 7
# L: 8
# L: 9
# L: 8
# L: 9
# L: 0
# L: 9
# L: 0
# L: 1
# L: 0
# L: 1
# L: 2
# L: 1
# L: 2
# L: 3
# L: 2
# L: 3
# L: 4
# L: 3
# L: 4
# L: 5
# L: 4
# L: 5
# L: 6
# L: 5
# L: 6
# L: 7
# L: 6
# L: 7
# L: 8
# L: 7
# L: 8
# L: 9
# L: 8
# L: 9
# L: 0
# L: 9
# L: 0
# L: 1
# IDX1: [60 60 60 60 60 60 60 60 60 60]
#   5%|▌         | 1/20 [00:01<00:31,  1.66s/it]
# check len os user: 0 1 len data 3512 3482
# check len os user: 0 2 len data 6296 2784
# check len os user: 1 0 len data 760 730
# check len os user: 1 1 len data 1540 780
#  10%|█         | 2/20 [00:01<00:14,  1.23it/s]
# check len os user: 1 2 len data 2194 654
# check len os user: 2 0 len data 1854 1824
# check len os user: 2 1 len data 2598 744
#  15%|█▌        | 3/20 [00:02<00:16,  1.06it/s]
# check len os user: 2 2 len data 3488 890
#  20%|██        | 4/20 [00:04<00:18,  1.13s/it]
# check len os user: 3 0 len data 3350 3320
# check len os user: 3 1 len data 3930 580
# check len os user: 3 2 len data 5564 1634
# check len os user: 4 0 len data 754 724
# check len os user: 4 1 len data 1188 434
#  25%|██▌       | 5/20 [00:04<00:12,  1.22it/s]
# check len os user: 4 2 len data 2768 1580
# check len os user: 5 0 len data 580 550
#  30%|███       | 6/20 [00:05<00:13,  1.03it/s]
# check len os user: 5 1 len data 1350 770
# check len os user: 5 2 len data 2020 670
# check len os user: 6 0 len data 936 906
#  35%|███▌      | 7/20 [00:06<00:10,  1.19it/s]
# check len os user: 6 1 len data 4524 3588
# check len os user: 6 2 len data 5818 1294
# check len os user: 7 0 len data 674 644
#  40%|████      | 8/20 [00:07<00:12,  1.05s/it]
# check len os user: 7 1 len data 1576 902
# check len os user: 7 2 len data 2230 654
# check len os user: 8 0 len data 586 556
# check len os user: 8 1 len data 1290 704
#  45%|████▌     | 9/20 [00:08<00:09,  1.21it/s]
# check len os user: 8 2 len data 3734 2444
# check len os user: 9 0 len data 678 648
# check len os user: 9 1 len data 1628 950
#  60%|██████    | 12/20 [00:08<00:03,  2.65it/s]
# check len os user: 9 2 len data 3092 1464
# check len os user: 10 0 len data 808 778
# check len os user: 11 2 len data 910 880
#  70%|███████   | 14/20 [00:10<00:03,  1.64it/s]
# check len os user: 12 2 len data 1086 1056
# check len os user: 13 1 len data 590 560
# check len os user: 13 2 len data 1456 866
# check len os user: 14 0 len data 504 474
# check len os user: 14 1 len data 1400 896
#  80%|████████  | 16/20 [00:11<00:01,  2.60it/s]
# check len os user: 14 2 len data 2088 688
# check len os user: 15 0 len data 826 796
# check len os user: 15 1 len data 1486 660
# check len os user: 16 1 len data 860 830
# check len os user: 16 2 len data 1474 614
#  90%|█████████ | 18/20 [00:11<00:00,  3.18it/s]
# check len os user: 17 1 len data 1092 1062
# check len os user: 17 2 len data 1848 756
# check len os user: 18 0 len data 1106 1076
# check len os user: 18 1 len data 1702 596
#  95%|█████████▌| 19/20 [00:12<00:00,  2.27it/s]
# check len os user: 18 2 len data 3214 1512
# check len os user: 19 0 len data 622 592
# 100%|██████████| 20/20 [00:14<00:00,  1.34it/s]
# IDX2: [5744 5736 5448 5658 4344 5236 4664 5792 5564 4010]
# Num_samples: [4722, 1645, 2616, 4173, 2076, 1515, 4363, 1672, 2800, 2319, 606, 682, 814, 1092, 1566, 1114, 1105, 1386, 2410, 466]
# Total_samples: 52196
# Finish Generating Samples
